# %%
import folium
from folium import IFrame
import json
import pandas as pd

# %%
df = pd.read_csv('wildfires_clean.csv', index_col=0)
# Out:
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.7/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
json = json.load(open('us-states.json'))

# %%
m = folium.Map(location=(40.373471, -95.843056), zoom_start=4)

# %%
choro = folium.Choropleth(
    geo_data=json,
    name='choropleth',
    data=area_by_st,
    columns=['state', 'id'],
    key_on='feature.id',
    fill_color='OrRd',
    nan_fill_color='red',
    fill_opacity=1,
    line_opacity=1,
    hightlight=True
).add_to(m)

# %%
m.save('test.html')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
json['features']
# Out:
# [{'type': 'Feature',
#   'id': 'AL',
#   'properties': {'name': 'Alabama'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-87.359296, 35.00118],
#      [-85.606675, 34.984749],
#      [-85.431413, 34.124869],
#      [-85.184951, 32.859696],
#      [-85.069935, 32.580372],
#      [-84.960397, 32.421541],
#      [-85.004212, 32.322956],
#      [-84.889196, 32.262709],
#      [-85.058981, 32.13674],
#      [-85.053504, 32.01077],
#      [-85.141136, 31.840985],
#      [-85.042551, 31.539753],
#      [-85.113751, 31.27686],
#      [-85.004212, 31.003013],
#      [-85.497137, 30.997536],
#      [-87.600282, 30.997536],
#      [-87.633143, 30.86609],
#      [-87.408589, 30.674397],
#      [-87.446927, 30.510088],
#      [-87.37025, 30.427934],
#      [-87.518128, 30.280057],
#      [-87.655051, 30.247195],
#      [-87.90699, 30.411504],
#      [-87.934375, 30.657966],
#      [-88.011052, 30.685351],
#      [-88.10416, 30.499135],
#      [-88.137022, 30.318396],
# ...

# %%
poly = shapely.geometry.shape(poly)

# %%
folium.GeoJsonTooltip()
# Out:
# -86.82778271419518

# %%
tooltip=folium.features.GeoJsonTooltip(
            fields=['name'],
            aliases=['State name:'])

# %%
tooltip.add_to(json)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-71c60b0a14f0> in <module>
# ----> 1 tooltip.add_to(json)
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.7/site-packages/branca/element.py in add_to(self, parent, name, index)
#     119     def add_to(self, parent, name=None, index=None):
#     120         """Add element to a parent."""
# --> 121         parent.add_child(self, name=name, index=index)
#     122         return self
#     123
#
# AttributeError: 'dict' object has no attribute 'add_child'

# %%
tooltip.add_to(choro.geojson)
